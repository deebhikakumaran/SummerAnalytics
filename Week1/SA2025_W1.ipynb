# %% [markdown]
# # SUMMER ANALYTICS 2025

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv('Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.columns.values
# Out:
# array(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'], dtype=object)

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.set_index('name')
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
df['mpg'].unique().tolist()
# Out:
# [18.0,
#  15.0,
#  16.0,
#  17.0,
#  14.0,
#  24.0,
#  22.0,
#  21.0,
#  27.0,
#  26.0,
#  25.0,
#  10.0,
#  11.0,
#  9.0,
#  28.0,
#  19.0,
#  12.0,
#  13.0,
#  23.0,
#  30.0,
#  31.0,
#  35.0,
#  20.0,
#  29.0,
#  32.0,
#  33.0,
#  17.5,
#  15.5,
#  14.5,
#  22.5,
#  24.5,
#  18.5,
#  29.5,
#  26.5,
#  16.5,
#  31.5,
#  36.0,
#  25.5,
#  33.5,
#  20.5,
#  30.5,
#  21.5,
#  43.1,
#  36.1,
#  32.8,
#  39.4,
#  19.9,
#  19.4,
#  20.2,
#  19.2,
#  25.1,
#  20.6,
#  20.8,
#  18.6,
#  18.1,
#  17.7,
#  27.5,
#  27.2,
#  30.9,
#  21.1,
#  23.2,
#  23.8,
#  23.9,
#  20.3,
#  21.6,
#  16.2,
#  19.8,
#  22.3,
#  17.6,
#  18.2,
#  16.9,
#  31.9,
#  34.1,
#  35.7,
#  27.4,
#  25.4,
#  34.2,
#  34.5,
#  31.8,
#  37.3,
#  28.4,
#  28.8,
#  26.8,
#  41.5,
#  38.1,
#  32.1,
#  37.2,
#  26.4,
#  24.3,
#  19.1,
#  34.3,
#  29.8,
#  31.3,
#  37.0,
#  32.2,
#  46.6,
#  27.9,
#  40.8,
#  44.3,
#  43.4,
#  36.4,
#  44.6,
#  40.9,
#  33.8,
#  32.7,
#  23.7,
#  23.6,
#  32.4,
#  26.6,
#  25.8,
#  23.5,
#  39.1,
#  39.0,
#  35.1,
#  32.3,
#  37.7,
#  34.7,
#  34.4,
#  29.9,
#  33.7,
#  32.9,
#  31.6,
#  28.1,
#  30.7,
#  24.2,
#  22.4,
#  34.0,
#  38.0,
#  44.0]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['new'] = df.horsepower / df.weight
df.set_index('new')
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# new
# 0.037100  18.0          8         307.0       130.0    3504          12.0
# 0.044679  15.0          8         350.0       165.0    3693          11.5
# 0.043655  18.0          8         318.0       150.0    3436          11.0
# 0.043694  16.0          8         304.0       150.0    3433          12.0
# 0.040591  17.0          8         302.0       140.0    3449          10.5
# ...        ...        ...           ...         ...     ...           ...
# 0.030824  27.0          4         140.0        86.0    2790          15.6
# 0.024413  44.0          4          97.0        52.0    2130          24.6
# 0.036601  32.0          4         135.0        84.0    2295          11.6
# 0.030095  28.0          4         120.0        79.0    2625          18.6
# 0.030147  31.0          4         119.0        82.0    2720          19.4
#
#           model_year  origin                       name
# new
# 0.037100          70     usa  chevrolet chevelle malibu
# 0.044679          70     usa          buick skylark 320
# 0.043655          70     usa         plymouth satellite
# 0.043694          70     usa              amc rebel sst
# 0.040591          70     usa                ford torino
# ...              ...     ...                        ...
# 0.030824          82     usa            ford mustang gl
# 0.024413          82  europe                  vw pickup
# 0.036601          82     usa              dodge rampage
# 0.030095          82     usa                ford ranger
# 0.030147          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp_car = df.loc[df['horsepower'].idxmax()]
print(max_hp_car['name'])
# Out:
# pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
cars_35_mpg = df[df['mpg'] >= 35]
num_cars_35_mpg = len(cars_35_mpg)
num_cars_35_mpg
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
filtered_cars = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
most_common_origin = filtered_cars['origin'].mode()[0]
most_common_origin
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
japan_cars = df[df['origin'] == 'japan']
mean_acceleration_japan = japan_cars['acceleration'].mean()
rounded_mean_acceleration = round(mean_acceleration_japan, 2)
rounded_mean_acceleration
# Out:
# np.float64(16.17)

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
df_avg_mpg_by_year = df.groupby('model_year')['mpg'].mean()
year_highest_avg_mpg = df_avg_mpg_by_year.idxmax()
year_highest_avg_mpg
# Out:
# np.int64(80)

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
df['hp_weight_ratio'] = df['horsepower'] / df['weight']
median_mpg = df['mpg'].median()
filtered_df = df[df['mpg'] > median_mpg]
max_ratio_car = filtered_df.loc[filtered_df['hp_weight_ratio'].idxmax()]
print(max_ratio_car['name'])
# Out:
# bmw 2002

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
import matplotlib.pyplot as plt

df = df.rename(columns={'model_year': 'year'})

# Group by year and origin, then calculate the mean mpg
avg_mpg_over_years_by_origin = df.groupby(['year', 'origin'])['mpg'].mean().reset_index()

# Plot the multi-line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_mpg_over_years_by_origin, x='year', y='mpg', hue='origin', marker='o')

plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Year')
plt.ylabel('Average MPG')
plt.grid(True)
plt.legend(title='Origin')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure the columns are of appropriate numeric types
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['mpg'] = pd.to_numeric(df['mpg'], errors='coerce')

# Drop rows with NaN values in the relevant columns if any coercion occurred
df.dropna(subset=['horsepower', 'weight', 'mpg', 'origin'], inplace=True)

# Create the scatterplot using Seaborn
plt.figure(figsize=(12, 8))
scatterplot = sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    sizes=(50, 500), # Adjust min and max size for the bubbles
    alpha=0.7,
    hue_order=['japan', 'europe', 'usa']
)

# Add titles and labels
plt.title('Horsepower vs. Weight by Origin and MPG', fontsize=16)
plt.xlabel('Horsepower', fontsize=12)
plt.ylabel('Weight', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Improve legend
scatterplot.legend(title='Origin', loc='upper right', bbox_to_anchor=(1.2, 1))

plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
# Filter for car names appearing in more than one year
car_counts = df['name'].value_counts()
multi_year_cars = car_counts[car_counts > 1].index

# Filter the DataFrame to include only these multi-year cars
df_multi_year = df[df['name'].isin(multi_year_cars)]

# Group by car name and compute std and mean of mpg
mpg_stats_by_car = df_multi_year.groupby('name')['mpg'].agg(['std', 'mean', 'count']).reset_index()

# Filter for cars with std(mpg) < 1.0 and count >= 2
consistent_cars = mpg_stats_by_car[(mpg_stats_by_car['std'] < 1.0) & (mpg_stats_by_car['count'] >= 2)]

# Find the car(s) with the lowest standard deviation among consistent cars
min_std = consistent_cars['std'].min()
lowest_variation_cars = consistent_cars[consistent_cars['std'] == min_std]

# Rename columns for clarity
lowest_variation_cars = lowest_variation_cars.rename(columns={'name': 'Model Name', 'count': 'Number of Appearances', 'mean': 'Average MPG'})

# Bonus: Sort the result
sorted_result = lowest_variation_cars.sort_values(by=['Number of Appearances', 'Average MPG'], ascending=[False, False])

# Report the result
print("Consistent Car(s) with Lowest Variation in MPG:")
print(sorted_result[['Model Name', 'Number of Appearances', 'Average MPG']])
# Out:
# Consistent Car(s) with Lowest Variation in MPG:
#       Model Name  Number of Appearances  Average MPG
# 21  datsun pl510                      2         27.0

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
